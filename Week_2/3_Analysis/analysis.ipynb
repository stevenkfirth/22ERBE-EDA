# %% [markdown]
# # Analysis week 2
#
# Demonstration of data analysis for **ERBE** week 2

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# ## Read csv file

# %%
df=pd.read_csv(r'../2_Simulation_data/eplusout.csv')
df
# Out:
#              Date/Time  \
# 0      12/21  01:00:00
# 1      12/21  02:00:00
# 2      12/21  03:00:00
# 3      12/21  04:00:00
# 4      12/21  05:00:00
# ...                ...
# 8803   12/31  20:00:00
# 8804   12/31  21:00:00
# 8805   12/31  22:00:00
# 8806   12/31  23:00:00
# 8807   12/31  24:00:00
#
#       Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)  \
# 0                                              -15.5000
# 1                                              -15.5000
# 2                                              -15.5000
# 3                                              -15.5000
# 4                                              -15.5000
# ...                                                 ...
# 8803                                            13.1125
# 8804                                            12.6125
# 8805                                            11.2000
# 8806                                            10.6000
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8808 entries, 0 to 8807
# Data columns (total 37 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Date/Time                                                                                8808 non-null   object
#  1   Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)                             8808 non-null   float64
#  2   Environment:Site Total Sky Cover [](Hourly)                                              8808 non-null   float64
#  3   Environment:Site Opaque Sky Cover [](Hourly)                                             8808 non-null   float64
#  4   Environment:Site Daylight Saving Time Status [](Daily)                                   367 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)  \
# count                                        8808.000000
# mean                                           13.741147
# std                                             4.179599
# min                                           -15.500000
# 25%                                            11.287500
# 50%                                            13.506250
# 75%                                            15.940625
# max                                            32.575000
#
#        Environment:Site Total Sky Cover [](Hourly)  \
# count                                  8808.000000
# mean                                      4.326096
# std                                       3.928992
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       3.250000
# 75%                                       8.625000
# ...

# %% [markdown]
# ## create figure

# %%
plt.rcParams.update({'font.size': 16})
fig, ax = plt.subplots(figsize=(16,6))
x=pd.date_range(start='1/1/2023', periods=8760, freq='H')
y=df['ZONE ONE:Zone Mean Air Temperature [C](Hourly)'][48:]
ax.plot(x,y,color='black', linewidth=0.5)
# x axis
ax.set_xlabel('Date & Time')
myFmt = mdates.DateFormatter('%b %Y')
ax.xaxis.set_major_formatter(myFmt)
# y axis
ax.set_ylabel('Temperature ($\degree$C)')
plt.savefig('Figure1.png',dpi=300)
plt.show()
print('Figure X: Mean hourly internal air temperature vs. date for the EnergyPlus simulation.')
# Out:
# Figure X: Mean hourly internal air temperature vs. date for the EnergyPlus simulation.

# %%
import matplotlib.pyplot as plt
import numpy as np

#plt.style.use('_mpl-gallery-nogrid')

# make data:
np.random.seed(1)
x = np.random.uniform(-3, 3, 256)
y = np.random.uniform(-3, 3, 256)
z = (1 - x/2 + x**5 + y**3) * np.exp(-x**2 - y**2)
levels = np.linspace(z.min(), z.max(), 7)

# plot:
fig, ax = plt.subplots()

ax.plot(x, y, 'o', markersize=2, color='grey')
ax.tricontourf(x, y, z, levels=levels)

ax.set(xlim=(-3, 3), ylim=(-3, 3))

plt.show()
